# %%
import pandas as pd
import matplotlib .pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv("canada_per_capita_income.csv")
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
model=linear_model.LinearRegression()

# %%
plt.scatter(df.year,df['per capita income (US$)'])

# %%
model.fit(df[['year']],df['per capita income (US$)'])
# Out:
# LinearRegression()

# %%
import numpy as np
input_data1 = np.array([2022]).reshape(-1, 1)
model.predict(input_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 import numpy as np
#       2 input_data1 = np.array([2022]).reshape(-1, 1)
# ----> 3 model.predict(input_data)
#
# NameError: name 'input_data' is not defined

# %%
plt.scatter(2022,model.predict(input_data1),color='red',marker='+')
plt.scatter(df.year,df['per capita income (US$)'])
k=model.predict(df[['year']])
input_data = np.array([k]).reshape(-1,1)
plt.plot(df.year,input_data)
plt.plot(2022,model.predict(input_data1),color="red")
# Out:
# C:\Users\ccaas\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\ccaas\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
